# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260723_092301"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 622 snapshots:
# Rendering 1/622: timestep 0
# /tmp/ipykernel_3228601/4260710794.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# Rendering 544/622: timestep 5430000
# Rendering 545/622: timestep 5440000
# Rendering 546/622: timestep 5450000
# Rendering 547/622: timestep 5460000
# Rendering 548/622: timestep 5470000
# Rendering 549/622: timestep 5480000
# Rendering 550/622: timestep 5490000
# Rendering 551/622: timestep 5500000
# Rendering 552/622: timestep 5510000
# Rendering 553/622: timestep 5520000
# Rendering 554/622: timestep 5530000
# Rendering 555/622: timestep 5540000
# Rendering 556/622: timestep 5550000
# Rendering 557/622: timestep 5560000
# Rendering 558/622: timestep 5570000
# Rendering 559/622: timestep 5580000
# Rendering 560/622: timestep 5590000
# Rendering 561/622: timestep 5600000
# Rendering 562/622: timestep 5610000
# Rendering 563/622: timestep 5620000
# Rendering 564/622: timestep 5630000
# Rendering 565/622: timestep 5640000
# Rendering 566/622: timestep 5650000
# Rendering 567/622: timestep 5660000
# Rendering 568/622: timestep 5670000
# Rendering 569/622: timestep 5680000
# Rendering 570/622: timestep 5690000
# Rendering 571/622: timestep 5700000
# Rendering 572/622: timestep 5710000
# Rendering 573/622: timestep 5720000
# Rendering 574/622: timestep 5730000
# Rendering 575/622: timestep 5740000
# Rendering 576/622: timestep 5750000
# Rendering 577/622: timestep 5760000
# Rendering 578/622: timestep 5770000
# Rendering 579/622: timestep 5780000
# Rendering 580/622: timestep 5790000
# Rendering 581/622: timestep 5800000
# Rendering 582/622: timestep 5810000
# Rendering 583/622: timestep 5820000
# Rendering 584/622: timestep 5830000
# Rendering 585/622: timestep 5840000
# Rendering 586/622: timestep 5850000
# Rendering 587/622: timestep 5860000
# Rendering 588/622: timestep 5870000
# Rendering 589/622: timestep 5880000
# Rendering 590/622: timestep 5890000
# Rendering 591/622: timestep 5900000
# Rendering 592/622: timestep 5910000
# Rendering 593/622: timestep 5920000
# Rendering 594/622: timestep 5930000
# Rendering 595/622: timestep 5940000
# Rendering 596/622: timestep 5950000
# Rendering 597/622: timestep 5960000
# Rendering 598/622: timestep 5970000
# Rendering 599/622: timestep 5980000
# Rendering 600/622: timestep 5990000
# Rendering 601/622: timestep 6000000
# Rendering 602/622: timestep 6010000
# Rendering 603/622: timestep 6020000
# Rendering 604/622: timestep 6030000
# Rendering 605/622: timestep 6040000
# Rendering 606/622: timestep 6050000
# Rendering 607/622: timestep 6060000
# Rendering 608/622: timestep 6070000
# Rendering 609/622: timestep 6080000
# Rendering 610/622: timestep 6090000
# Rendering 611/622: timestep 6100000
# Rendering 612/622: timestep 6110000
# Rendering 613/622: timestep 6120000
# Rendering 614/622: timestep 6130000
# Rendering 615/622: timestep 6140000
# Rendering 616/622: timestep 6150000
# Rendering 617/622: timestep 6160000
# Rendering 618/622: timestep 6170000
# Rendering 619/622: timestep 6180000
# Rendering 620/622: timestep 6190000
# Rendering 621/622: timestep 6200000
# Rendering 622/622: timestep 6210000
# ✅ 2D contour animation saved to: ../outputs/Results/20260723_092301/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
