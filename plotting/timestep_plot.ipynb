# %% [markdown]
# The below code is for a 3D Plot

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20251209_134446__nsteps=3001__mesh=II_1_bin"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")
# Out:
# Found 7 snapshots:
# Rendering 1/7: timestep 0
# /tmp/ipykernel_467581/757391451.py:90: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/7: timestep 500
# Rendering 3/7: timestep 1000
# Rendering 4/7: timestep 1500
# Rendering 5/7: timestep 2000
# Rendering 6/7: timestep 2500
# Rendering 7/7: timestep 3000
# ✅ Animation saved to: ../outputs/Results/20251209_134446__nsteps=3001__mesh=II_1_bin/CnE_animation.gif

# %% [markdown]
# The below code is used for the 2D Contour Plot

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260113_135124__nsteps=120000__mesh=II_1_bin"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "CnP_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 120 snapshots:
# Rendering 1/120: timestep 0
# /tmp/ipykernel_2564332/3190560323.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/120: timestep 1000
# Rendering 3/120: timestep 2000
# Rendering 4/120: timestep 3000
# Rendering 5/120: timestep 4000
# Rendering 6/120: timestep 5000
# Rendering 7/120: timestep 6000
# Rendering 8/120: timestep 7000
# Rendering 9/120: timestep 8000
# Rendering 10/120: timestep 9000
# Rendering 11/120: timestep 10000
# Rendering 12/120: timestep 11000
# Rendering 13/120: timestep 12000
# Rendering 14/120: timestep 13000
# Rendering 15/120: timestep 14000
# Rendering 16/120: timestep 15000
# Rendering 17/120: timestep 16000
# Rendering 18/120: timestep 17000
# Rendering 19/120: timestep 18000
# Rendering 20/120: timestep 19000
# Rendering 21/120: timestep 20000
# Rendering 22/120: timestep 21000
# Rendering 23/120: timestep 22000
# Rendering 24/120: timestep 23000
# Rendering 25/120: timestep 24000
# Rendering 26/120: timestep 25000
# Rendering 27/120: timestep 26000
# Rendering 28/120: timestep 27000
# Rendering 29/120: timestep 28000
# Rendering 30/120: timestep 29000
# Rendering 31/120: timestep 30000
# Rendering 32/120: timestep 31000
# Rendering 33/120: timestep 32000
# Rendering 34/120: timestep 33000
# Rendering 35/120: timestep 34000
# Rendering 36/120: timestep 35000
# Rendering 37/120: timestep 36000
# Rendering 38/120: timestep 37000
# Rendering 39/120: timestep 38000
# Rendering 40/120: timestep 39000
# Rendering 41/120: timestep 40000
# Rendering 42/120: timestep 41000
# Rendering 43/120: timestep 42000
# Rendering 44/120: timestep 43000
# Rendering 45/120: timestep 44000
# Rendering 46/120: timestep 45000
# Rendering 47/120: timestep 46000
# Rendering 48/120: timestep 47000
# Rendering 49/120: timestep 48000
# Rendering 50/120: timestep 49000
# Rendering 51/120: timestep 50000
# Rendering 52/120: timestep 51000
# Rendering 53/120: timestep 52000
# Rendering 54/120: timestep 53000
# Rendering 55/120: timestep 54000
# Rendering 56/120: timestep 55000
# Rendering 57/120: timestep 56000
# Rendering 58/120: timestep 57000
# Rendering 59/120: timestep 58000
# Rendering 60/120: timestep 59000
# Rendering 61/120: timestep 60000
# Rendering 62/120: timestep 61000
# Rendering 63/120: timestep 62000
# Rendering 64/120: timestep 63000
# Rendering 65/120: timestep 64000
# Rendering 66/120: timestep 65000
# Rendering 67/120: timestep 66000
# Rendering 68/120: timestep 67000
# Rendering 69/120: timestep 68000
# Rendering 70/120: timestep 69000
# Rendering 71/120: timestep 70000
# Rendering 72/120: timestep 71000
# Rendering 73/120: timestep 72000
# Rendering 74/120: timestep 73000
# Rendering 75/120: timestep 74000
# Rendering 76/120: timestep 75000
# Rendering 77/120: timestep 76000
# Rendering 78/120: timestep 77000
# Rendering 79/120: timestep 78000
# Rendering 80/120: timestep 79000
# Rendering 81/120: timestep 80000
# Rendering 82/120: timestep 81000
# Rendering 83/120: timestep 82000
# Rendering 84/120: timestep 83000
# Rendering 85/120: timestep 84000
# Rendering 86/120: timestep 85000
# Rendering 87/120: timestep 86000
# Rendering 88/120: timestep 87000
# Rendering 89/120: timestep 88000
# Rendering 90/120: timestep 89000
# Rendering 91/120: timestep 90000
# Rendering 92/120: timestep 91000
# Rendering 93/120: timestep 92000
# Rendering 94/120: timestep 93000
# Rendering 95/120: timestep 94000
# Rendering 96/120: timestep 95000
# Rendering 97/120: timestep 96000
# Rendering 98/120: timestep 97000
# Rendering 99/120: timestep 98000
# Rendering 100/120: timestep 99000
# Rendering 101/120: timestep 100000
# Rendering 102/120: timestep 101000
# Rendering 103/120: timestep 102000
# Rendering 104/120: timestep 103000
# Rendering 105/120: timestep 104000
# Rendering 106/120: timestep 105000
# Rendering 107/120: timestep 106000
# Rendering 108/120: timestep 107000
# Rendering 109/120: timestep 108000
# Rendering 110/120: timestep 109000
# Rendering 111/120: timestep 110000
# Rendering 112/120: timestep 111000
# Rendering 113/120: timestep 112000
# Rendering 114/120: timestep 113000
# Rendering 115/120: timestep 114000
# Rendering 116/120: timestep 115000
# Rendering 117/120: timestep 116000
# Rendering 118/120: timestep 117000
# Rendering 119/120: timestep 118000
# Rendering 120/120: timestep 119000
# ✅ 2D contour animation saved to: ../outputs/Results/20260113_135124__nsteps=120000__mesh=II_1_bin/CnP_contour_animation.gif

# %%
pip install imageio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imageio
#   Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.6/317.6 KB 5.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /mnt/ffs24/home/brandlan/.local/lib/python3.10/site-packages (from imageio) (2.2.6)
# Requirement already satisfied: pillow>=8.3.2 in /mnt/ffs24/home/brandlan/.local/lib/python3.10/site-packages (from imageio) (12.0.0)
# Installing collected packages: imageio
# Successfully installed imageio-2.37.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
