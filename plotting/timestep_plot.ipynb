# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260801_221458"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnA_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnA_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 371 snapshots:
# Rendering 1/371: timestep 0
# /tmp/ipykernel_3799313/1855759504.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/371: timestep 5000
# Rendering 3/371: timestep 10000
# Rendering 4/371: timestep 15000
# Rendering 5/371: timestep 20000
# Rendering 6/371: timestep 25000
# Rendering 7/371: timestep 30000
# Rendering 8/371: timestep 35000
# Rendering 9/371: timestep 40000
# Rendering 10/371: timestep 45000
# Rendering 11/371: timestep 50000
# Rendering 12/371: timestep 55000
# Rendering 13/371: timestep 60000
# Rendering 14/371: timestep 65000
# Rendering 15/371: timestep 70000
# Rendering 16/371: timestep 75000
# Rendering 17/371: timestep 80000
# Rendering 18/371: timestep 85000
# Rendering 19/371: timestep 90000
# Rendering 20/371: timestep 95000
# Rendering 21/371: timestep 100000
# Rendering 22/371: timestep 105000
# Rendering 23/371: timestep 110000
# Rendering 24/371: timestep 115000
# Rendering 25/371: timestep 120000
# Rendering 26/371: timestep 125000
# Rendering 27/371: timestep 130000
# Rendering 28/371: timestep 135000
# Rendering 29/371: timestep 140000
# Rendering 30/371: timestep 145000
# Rendering 31/371: timestep 150000
# Rendering 32/371: timestep 155000
# Rendering 33/371: timestep 160000
# Rendering 34/371: timestep 165000
# Rendering 35/371: timestep 170000
# Rendering 36/371: timestep 175000
# Rendering 37/371: timestep 180000
# Rendering 38/371: timestep 185000
# Rendering 39/371: timestep 190000
# Rendering 40/371: timestep 195000
# Rendering 299/371: timestep 1490000
# Rendering 300/371: timestep 1495000
# Rendering 301/371: timestep 1500000
# Rendering 302/371: timestep 1505000
# Rendering 303/371: timestep 1510000
# Rendering 304/371: timestep 1515000
# Rendering 305/371: timestep 1520000
# Rendering 306/371: timestep 1525000
# Rendering 307/371: timestep 1530000
# Rendering 308/371: timestep 1535000
# Rendering 309/371: timestep 1540000
# Rendering 310/371: timestep 1545000
# Rendering 311/371: timestep 1550000
# Rendering 312/371: timestep 1555000
# Rendering 313/371: timestep 1560000
# Rendering 314/371: timestep 1565000
# Rendering 315/371: timestep 1570000
# Rendering 316/371: timestep 1575000
# Rendering 317/371: timestep 1580000
# Rendering 318/371: timestep 1585000
# Rendering 319/371: timestep 1590000
# Rendering 320/371: timestep 1595000
# Rendering 321/371: timestep 1600000
# Rendering 322/371: timestep 1605000
# Rendering 323/371: timestep 1610000
# Rendering 324/371: timestep 1615000
# Rendering 325/371: timestep 1620000
# Rendering 326/371: timestep 1625000
# Rendering 327/371: timestep 1630000
# Rendering 328/371: timestep 1635000
# Rendering 329/371: timestep 1640000
# Rendering 330/371: timestep 1645000
# Rendering 331/371: timestep 1650000
# Rendering 332/371: timestep 1655000
# Rendering 333/371: timestep 1660000
# Rendering 334/371: timestep 1665000
# Rendering 335/371: timestep 1670000
# Rendering 336/371: timestep 1675000
# Rendering 337/371: timestep 1680000
# Rendering 338/371: timestep 1685000
# Rendering 339/371: timestep 1690000
# Rendering 340/371: timestep 1695000
# Rendering 341/371: timestep 1700000
# Rendering 342/371: timestep 1705000
# Rendering 343/371: timestep 1710000
# Rendering 344/371: timestep 1715000
# Rendering 345/371: timestep 1720000
# Rendering 346/371: timestep 1725000
# Rendering 347/371: timestep 1730000
# Rendering 348/371: timestep 1735000
# Rendering 349/371: timestep 1740000
# Rendering 350/371: timestep 1745000
# Rendering 351/371: timestep 1750000
# Rendering 352/371: timestep 1755000
# Rendering 353/371: timestep 1760000
# Rendering 354/371: timestep 1765000
# Rendering 355/371: timestep 1770000
# Rendering 356/371: timestep 1775000
# Rendering 357/371: timestep 1780000
# Rendering 358/371: timestep 1785000
# Rendering 359/371: timestep 1790000
# Rendering 360/371: timestep 1795000
# Rendering 361/371: timestep 1800000
# Rendering 362/371: timestep 1805000
# Rendering 363/371: timestep 1810000
# Rendering 364/371: timestep 1815000
# Rendering 365/371: timestep 1820000
# Rendering 366/371: timestep 1825000
# Rendering 367/371: timestep 1830000
# Rendering 368/371: timestep 1835000
# Rendering 369/371: timestep 1840000
# Rendering 370/371: timestep 1845000
# Rendering 371/371: timestep 1850000
# ✅ 2D contour animation saved to: ../outputs/Results/20260731_150049/CnA_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
