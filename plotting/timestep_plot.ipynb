# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20251209_134446__nsteps=3001__mesh=II_1_bin"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260413_153123__nsteps=100__mesh=Mesh_40x60_F00"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "CnP_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 150 snapshots:
# Rendering 1/150: timestep 0
# /tmp/ipykernel_3364271/2882386628.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/150: timestep 1000
# Rendering 3/150: timestep 2000
# Rendering 4/150: timestep 3000
# Rendering 5/150: timestep 4000
# Rendering 6/150: timestep 5000
# Rendering 7/150: timestep 6000
# Rendering 8/150: timestep 7000
# Rendering 9/150: timestep 8000
# Rendering 10/150: timestep 9000
# Rendering 11/150: timestep 10000
# Rendering 12/150: timestep 11000
# Rendering 13/150: timestep 12000
# Rendering 14/150: timestep 13000
# Rendering 15/150: timestep 14000
# Rendering 16/150: timestep 15000
# Rendering 17/150: timestep 16000
# Rendering 18/150: timestep 17000
# Rendering 19/150: timestep 18000
# Rendering 20/150: timestep 19000
# Rendering 21/150: timestep 20000
# Rendering 22/150: timestep 21000
# Rendering 23/150: timestep 22000
# Rendering 24/150: timestep 23000
# Rendering 25/150: timestep 24000
# Rendering 26/150: timestep 25000
# Rendering 27/150: timestep 26000
# Rendering 28/150: timestep 27000
# Rendering 29/150: timestep 28000
# Rendering 30/150: timestep 29000
# Rendering 31/150: timestep 30000
# Rendering 32/150: timestep 31000
# Rendering 33/150: timestep 32000
# Rendering 34/150: timestep 33000
# Rendering 35/150: timestep 34000
# Rendering 36/150: timestep 35000
# Rendering 37/150: timestep 36000
# Rendering 38/150: timestep 37000
# Rendering 39/150: timestep 38000
# Rendering 40/150: timestep 39000
# Rendering 41/150: timestep 40000
# Rendering 42/150: timestep 41000
# Rendering 43/150: timestep 42000
# Rendering 44/150: timestep 43000
# Rendering 45/150: timestep 44000
# Rendering 46/150: timestep 45000
# Rendering 47/150: timestep 46000
# Rendering 48/150: timestep 47000
# Rendering 49/150: timestep 48000
# Rendering 50/150: timestep 49000
# Rendering 51/150: timestep 50000
# Rendering 52/150: timestep 51000
# Rendering 53/150: timestep 52000
# Rendering 54/150: timestep 53000
# Rendering 55/150: timestep 54000
# Rendering 56/150: timestep 55000
# Rendering 57/150: timestep 56000
# Rendering 58/150: timestep 57000
# Rendering 59/150: timestep 58000
# Rendering 60/150: timestep 59000
# Rendering 61/150: timestep 60000
# Rendering 62/150: timestep 61000
# Rendering 63/150: timestep 62000
# Rendering 64/150: timestep 63000
# Rendering 65/150: timestep 64000
# Rendering 66/150: timestep 65000
# Rendering 67/150: timestep 66000
# Rendering 68/150: timestep 67000
# Rendering 69/150: timestep 68000
# Rendering 70/150: timestep 69000
# Rendering 71/150: timestep 70000
# Rendering 72/150: timestep 71000
# Rendering 73/150: timestep 72000
# Rendering 74/150: timestep 73000
# Rendering 75/150: timestep 74000
# Rendering 76/150: timestep 75000
# Rendering 77/150: timestep 76000
# Rendering 78/150: timestep 77000
# Rendering 79/150: timestep 78000
# Rendering 80/150: timestep 79000
# Rendering 81/150: timestep 80000
# Rendering 82/150: timestep 81000
# Rendering 83/150: timestep 82000
# Rendering 84/150: timestep 83000
# Rendering 85/150: timestep 84000
# Rendering 86/150: timestep 85000
# Rendering 87/150: timestep 86000
# Rendering 88/150: timestep 87000
# Rendering 89/150: timestep 88000
# Rendering 90/150: timestep 89000
# Rendering 91/150: timestep 90000
# Rendering 92/150: timestep 91000
# Rendering 93/150: timestep 92000
# Rendering 94/150: timestep 93000
# Rendering 95/150: timestep 94000
# Rendering 96/150: timestep 95000
# Rendering 97/150: timestep 96000
# Rendering 98/150: timestep 97000
# Rendering 99/150: timestep 98000
# Rendering 100/150: timestep 99000
# Rendering 101/150: timestep 100000
# Rendering 102/150: timestep 101000
# Rendering 103/150: timestep 102000
# Rendering 104/150: timestep 103000
# Rendering 105/150: timestep 104000
# Rendering 106/150: timestep 105000
# Rendering 107/150: timestep 106000
# Rendering 108/150: timestep 107000
# Rendering 109/150: timestep 108000
# Rendering 110/150: timestep 109000
# Rendering 111/150: timestep 110000
# Rendering 112/150: timestep 111000
# Rendering 113/150: timestep 112000
# Rendering 114/150: timestep 113000
# Rendering 115/150: timestep 114000
# Rendering 116/150: timestep 115000
# Rendering 117/150: timestep 116000
# Rendering 118/150: timestep 117000
# Rendering 119/150: timestep 118000
# Rendering 120/150: timestep 119000
# Rendering 121/150: timestep 120000
# Rendering 122/150: timestep 121000
# Rendering 123/150: timestep 122000
# Rendering 124/150: timestep 123000
# Rendering 125/150: timestep 124000
# Rendering 126/150: timestep 125000
# Rendering 127/150: timestep 126000
# Rendering 128/150: timestep 127000
# Rendering 129/150: timestep 128000
# Rendering 130/150: timestep 129000
# Rendering 131/150: timestep 130000
# Rendering 132/150: timestep 131000
# Rendering 133/150: timestep 132000
# Rendering 134/150: timestep 133000
# Rendering 135/150: timestep 134000
# Rendering 136/150: timestep 135000
# Rendering 137/150: timestep 136000
# Rendering 138/150: timestep 137000
# Rendering 139/150: timestep 138000
# Rendering 140/150: timestep 139000
# Rendering 141/150: timestep 140000
# Rendering 142/150: timestep 141000
# Rendering 143/150: timestep 142000
# Rendering 144/150: timestep 143000
# Rendering 145/150: timestep 144000
# Rendering 146/150: timestep 145000
# Rendering 147/150: timestep 146000
# Rendering 148/150: timestep 147000
# Rendering 149/150: timestep 148000
# Rendering 150/150: timestep 149000
# ✅ 2D contour animation saved to: ../outputs/Results/20260413_153123__nsteps=100__mesh=Mesh_40x60_F00/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
