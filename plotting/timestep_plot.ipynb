# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260704_092935__nsteps=1__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260715_191823"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=0.05)
levels = np.linspace(0, 0.05, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 0.05) # Forcing values within [0, 0.0433]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 243 snapshots:
# Rendering 1/243: timestep 0
# /tmp/ipykernel_3136614/1879868084.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# Rendering 172/243: timestep 1710000
# Rendering 173/243: timestep 1720000
# Rendering 174/243: timestep 1730000
# Rendering 175/243: timestep 1740000
# Rendering 176/243: timestep 1750000
# Rendering 177/243: timestep 1760000
# Rendering 178/243: timestep 1770000
# Rendering 179/243: timestep 1780000
# Rendering 180/243: timestep 1790000
# Rendering 181/243: timestep 1800000
# Rendering 182/243: timestep 1810000
# Rendering 183/243: timestep 1820000
# Rendering 184/243: timestep 1830000
# Rendering 185/243: timestep 1840000
# Rendering 186/243: timestep 1850000
# Rendering 187/243: timestep 1860000
# Rendering 188/243: timestep 1870000
# Rendering 189/243: timestep 1880000
# Rendering 190/243: timestep 1890000
# Rendering 191/243: timestep 1900000
# Rendering 192/243: timestep 1910000
# Rendering 193/243: timestep 1920000
# Rendering 194/243: timestep 1930000
# Rendering 195/243: timestep 1940000
# Rendering 196/243: timestep 1950000
# Rendering 197/243: timestep 1960000
# Rendering 198/243: timestep 1970000
# Rendering 199/243: timestep 1980000
# Rendering 200/243: timestep 1990000
# Rendering 201/243: timestep 2000000
# Rendering 202/243: timestep 2010000
# Rendering 203/243: timestep 2020000
# Rendering 204/243: timestep 2030000
# Rendering 205/243: timestep 2040000
# Rendering 206/243: timestep 2050000
# Rendering 207/243: timestep 2060000
# Rendering 208/243: timestep 2070000
# Rendering 209/243: timestep 2080000
# Rendering 210/243: timestep 2090000
# Rendering 211/243: timestep 2100000
# Rendering 212/243: timestep 2110000
# Rendering 213/243: timestep 2120000
# Rendering 214/243: timestep 2130000
# Rendering 215/243: timestep 2140000
# Rendering 216/243: timestep 2150000
# Rendering 217/243: timestep 2160000
# Rendering 218/243: timestep 2170000
# Rendering 219/243: timestep 2180000
# Rendering 220/243: timestep 2190000
# Rendering 221/243: timestep 2200000
# Rendering 222/243: timestep 2210000
# Rendering 223/243: timestep 2220000
# Rendering 224/243: timestep 2230000
# Rendering 225/243: timestep 2240000
# Rendering 226/243: timestep 2250000
# Rendering 227/243: timestep 2260000
# Rendering 228/243: timestep 2270000
# Rendering 229/243: timestep 2280000
# Rendering 230/243: timestep 2290000
# Rendering 231/243: timestep 2300000
# Rendering 232/243: timestep 2310000
# Rendering 233/243: timestep 2320000
# Rendering 234/243: timestep 2330000
# Rendering 235/243: timestep 2340000
# Rendering 236/243: timestep 2350000
# Rendering 237/243: timestep 2360000
# Rendering 238/243: timestep 2370000
# Rendering 239/243: timestep 2380000
# Rendering 240/243: timestep 2390000
# Rendering 241/243: timestep 2400000
# Rendering 242/243: timestep 2410000
# Rendering 243/243: timestep 2420000
# ✅ 2D contour animation saved to: ../outputs/Results/20260715_131712/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
