# %% [markdown]
# The below code is for a 3D Plot

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20251209_134446__nsteps=3001__mesh=II_1_bin"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# The below code is used for the 2D Contour Plot

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260116_115320__nsteps=300000__mesh=rectangle3"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "CnP_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 80 snapshots:
# Rendering 1/80: timestep 0
# Rendering 2/80: timestep 1000
# /tmp/ipykernel_3318622/2813098645.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 3/80: timestep 2000
# Rendering 4/80: timestep 3000
# Rendering 5/80: timestep 4000
# Rendering 6/80: timestep 5000
# Rendering 7/80: timestep 6000
# Rendering 8/80: timestep 7000
# Rendering 9/80: timestep 8000
# Rendering 10/80: timestep 9000
# Rendering 11/80: timestep 10000
# Rendering 12/80: timestep 11000
# Rendering 13/80: timestep 12000
# Rendering 14/80: timestep 13000
# Rendering 15/80: timestep 14000
# Rendering 16/80: timestep 15000
# Rendering 17/80: timestep 16000
# Rendering 18/80: timestep 17000
# Rendering 19/80: timestep 18000
# Rendering 20/80: timestep 19000
# Rendering 21/80: timestep 20000
# Rendering 22/80: timestep 21000
# Rendering 23/80: timestep 22000
# Rendering 24/80: timestep 23000
# Rendering 25/80: timestep 24000
# Rendering 26/80: timestep 25000
# Rendering 27/80: timestep 26000
# Rendering 28/80: timestep 27000
# Rendering 29/80: timestep 28000
# Rendering 30/80: timestep 29000
# Rendering 31/80: timestep 30000
# Rendering 32/80: timestep 31000
# Rendering 33/80: timestep 32000
# Rendering 34/80: timestep 33000
# Rendering 35/80: timestep 34000
# Rendering 36/80: timestep 35000
# Rendering 37/80: timestep 36000
# Rendering 38/80: timestep 37000
# Rendering 39/80: timestep 38000
# Rendering 40/80: timestep 39000
# Rendering 41/80: timestep 40000
# Rendering 42/80: timestep 41000
# Rendering 43/80: timestep 42000
# Rendering 44/80: timestep 43000
# Rendering 45/80: timestep 44000
# Rendering 46/80: timestep 45000
# Rendering 47/80: timestep 46000
# Rendering 48/80: timestep 47000
# Rendering 49/80: timestep 48000
# Rendering 50/80: timestep 49000
# Rendering 51/80: timestep 50000
# Rendering 52/80: timestep 51000
# Rendering 53/80: timestep 52000
# Rendering 54/80: timestep 53000
# Rendering 55/80: timestep 54000
# Rendering 56/80: timestep 55000
# Rendering 57/80: timestep 56000
# Rendering 58/80: timestep 57000
# Rendering 59/80: timestep 58000
# Rendering 60/80: timestep 59000
# Rendering 61/80: timestep 60000
# Rendering 62/80: timestep 61000
# Rendering 63/80: timestep 62000
# Rendering 64/80: timestep 63000
# Rendering 65/80: timestep 64000
# Rendering 66/80: timestep 65000
# Rendering 67/80: timestep 66000
# Rendering 68/80: timestep 67000
# Rendering 69/80: timestep 68000
# Rendering 70/80: timestep 69000
# Rendering 71/80: timestep 70000
# Rendering 72/80: timestep 71000
# Rendering 73/80: timestep 72000
# Rendering 74/80: timestep 73000
# Rendering 75/80: timestep 74000
# Rendering 76/80: timestep 75000
# Rendering 77/80: timestep 76000
# Rendering 78/80: timestep 77000
# Rendering 79/80: timestep 78000
# Rendering 80/80: timestep 79000
# ✅ 2D contour animation saved to: ../outputs/Results/20260116_114954__nsteps=80000__mesh=rectangle3/CnP_contour_animation.gif

# %%
pip install imageio

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
