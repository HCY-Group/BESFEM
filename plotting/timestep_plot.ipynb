# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260727_215837"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnC_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnC_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 311 snapshots:
# Rendering 1/311: timestep 0
# /tmp/ipykernel_1668450/2266158587.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/311: timestep 1000
# Rendering 3/311: timestep 2000
# Rendering 4/311: timestep 3000
# Rendering 5/311: timestep 4000
# Rendering 6/311: timestep 5000
# Rendering 7/311: timestep 6000
# Rendering 8/311: timestep 7000
# Rendering 9/311: timestep 8000
# Rendering 10/311: timestep 9000
# Rendering 11/311: timestep 10000
# Rendering 12/311: timestep 11000
# Rendering 13/311: timestep 12000
# Rendering 14/311: timestep 13000
# Rendering 15/311: timestep 14000
# Rendering 16/311: timestep 15000
# Rendering 17/311: timestep 16000
# Rendering 18/311: timestep 17000
# Rendering 19/311: timestep 18000
# Rendering 20/311: timestep 19000
# Rendering 21/311: timestep 20000
# Rendering 22/311: timestep 21000
# Rendering 23/311: timestep 22000
# Rendering 24/311: timestep 23000
# Rendering 25/311: timestep 24000
# Rendering 26/311: timestep 25000
# Rendering 27/311: timestep 26000
# Rendering 28/311: timestep 27000
# Rendering 29/311: timestep 28000
# Rendering 30/311: timestep 29000
# Rendering 31/311: timestep 30000
# Rendering 32/311: timestep 31000
# Rendering 33/311: timestep 32000
# Rendering 34/311: timestep 33000
# Rendering 35/311: timestep 34000
# Rendering 36/311: timestep 35000
# Rendering 37/311: timestep 36000
# Rendering 38/311: timestep 37000
# Rendering 39/311: timestep 38000
# Rendering 40/311: timestep 39000
# Rendering 41/311: timestep 40000
# Rendering 42/311: timestep 41000
# Rendering 43/311: timestep 42000
# Rendering 44/311: timestep 43000
# Rendering 45/311: timestep 44000
# Rendering 46/311: timestep 45000
# Rendering 47/311: timestep 46000
# Rendering 48/311: timestep 47000
# Rendering 49/311: timestep 48000
# Rendering 50/311: timestep 49000
# Rendering 51/311: timestep 50000
# Rendering 52/311: timestep 51000
# Rendering 53/311: timestep 52000
# Rendering 54/311: timestep 53000
# Rendering 55/311: timestep 54000
# Rendering 56/311: timestep 55000
# Rendering 57/311: timestep 56000
# Rendering 58/311: timestep 57000
# Rendering 59/311: timestep 58000
# Rendering 60/311: timestep 59000
# Rendering 61/311: timestep 60000
# Rendering 62/311: timestep 61000
# Rendering 63/311: timestep 62000
# Rendering 64/311: timestep 63000
# Rendering 65/311: timestep 64000
# Rendering 66/311: timestep 65000
# Rendering 67/311: timestep 66000
# Rendering 68/311: timestep 67000
# Rendering 69/311: timestep 68000
# Rendering 70/311: timestep 69000
# Rendering 71/311: timestep 70000
# Rendering 72/311: timestep 71000
# Rendering 73/311: timestep 72000
# Rendering 74/311: timestep 73000
# Rendering 75/311: timestep 74000
# Rendering 76/311: timestep 75000
# Rendering 77/311: timestep 76000
# Rendering 78/311: timestep 77000
# Rendering 79/311: timestep 78000
# Rendering 80/311: timestep 79000
# Rendering 81/311: timestep 80000
# Rendering 82/311: timestep 81000
# Rendering 83/311: timestep 82000
# Rendering 84/311: timestep 83000
# Rendering 85/311: timestep 84000
# Rendering 86/311: timestep 85000
# Rendering 87/311: timestep 86000
# Rendering 88/311: timestep 87000
# Rendering 89/311: timestep 88000
# Rendering 90/311: timestep 89000
# Rendering 91/311: timestep 90000
# Rendering 92/311: timestep 91000
# Rendering 93/311: timestep 92000
# Rendering 94/311: timestep 93000
# Rendering 95/311: timestep 94000
# Rendering 96/311: timestep 95000
# Rendering 97/311: timestep 96000
# Rendering 98/311: timestep 97000
# Rendering 99/311: timestep 98000
# Rendering 100/311: timestep 99000
# Rendering 101/311: timestep 100000
# Rendering 102/311: timestep 101000
# Rendering 103/311: timestep 102000
# Rendering 104/311: timestep 103000
# Rendering 105/311: timestep 104000
# Rendering 106/311: timestep 105000
# Rendering 107/311: timestep 106000
# Rendering 108/311: timestep 107000
# Rendering 109/311: timestep 108000
# Rendering 110/311: timestep 109000
# Rendering 111/311: timestep 110000
# Rendering 112/311: timestep 111000
# Rendering 113/311: timestep 112000
# Rendering 114/311: timestep 113000
# Rendering 115/311: timestep 114000
# Rendering 116/311: timestep 115000
# Rendering 117/311: timestep 116000
# Rendering 118/311: timestep 117000
# Rendering 119/311: timestep 118000
# Rendering 120/311: timestep 119000
# Rendering 121/311: timestep 120000
# Rendering 122/311: timestep 121000
# Rendering 123/311: timestep 122000
# Rendering 124/311: timestep 123000
# Rendering 125/311: timestep 124000
# Rendering 126/311: timestep 125000
# Rendering 127/311: timestep 126000
# Rendering 128/311: timestep 127000
# Rendering 129/311: timestep 128000
# Rendering 130/311: timestep 129000
# Rendering 131/311: timestep 130000
# Rendering 132/311: timestep 131000
# Rendering 133/311: timestep 132000
# Rendering 134/311: timestep 133000
# Rendering 135/311: timestep 134000
# Rendering 136/311: timestep 135000
# Rendering 137/311: timestep 136000
# Rendering 138/311: timestep 137000
# Rendering 139/311: timestep 138000
# Rendering 140/311: timestep 139000
# Rendering 141/311: timestep 140000
# Rendering 142/311: timestep 141000
# Rendering 143/311: timestep 142000
# Rendering 144/311: timestep 143000
# Rendering 145/311: timestep 144000
# Rendering 146/311: timestep 145000
# Rendering 147/311: timestep 146000
# Rendering 148/311: timestep 147000
# Rendering 149/311: timestep 148000
# Rendering 150/311: timestep 149000
# Rendering 151/311: timestep 150000
# Rendering 152/311: timestep 151000
# Rendering 153/311: timestep 152000
# Rendering 154/311: timestep 153000
# Rendering 155/311: timestep 154000
# Rendering 156/311: timestep 155000
# Rendering 157/311: timestep 156000
# Rendering 158/311: timestep 157000
# Rendering 159/311: timestep 158000
# Rendering 160/311: timestep 159000
# Rendering 161/311: timestep 160000
# Rendering 162/311: timestep 161000
# Rendering 163/311: timestep 162000
# Rendering 164/311: timestep 163000
# Rendering 165/311: timestep 164000
# Rendering 166/311: timestep 165000
# Rendering 167/311: timestep 166000
# Rendering 168/311: timestep 167000
# Rendering 169/311: timestep 168000
# Rendering 170/311: timestep 169000
# Rendering 171/311: timestep 170000
# Rendering 172/311: timestep 171000
# Rendering 173/311: timestep 172000
# Rendering 174/311: timestep 173000
# Rendering 175/311: timestep 174000
# Rendering 176/311: timestep 175000
# Rendering 177/311: timestep 176000
# Rendering 178/311: timestep 177000
# Rendering 179/311: timestep 178000
# Rendering 180/311: timestep 179000
# Rendering 181/311: timestep 180000
# Rendering 182/311: timestep 181000
# Rendering 183/311: timestep 182000
# Rendering 184/311: timestep 183000
# Rendering 185/311: timestep 184000
# Rendering 186/311: timestep 185000
# Rendering 187/311: timestep 186000
# Rendering 188/311: timestep 187000
# Rendering 189/311: timestep 188000
# Rendering 190/311: timestep 189000
# Rendering 191/311: timestep 190000
# Rendering 192/311: timestep 191000
# Rendering 193/311: timestep 192000
# Rendering 194/311: timestep 193000
# Rendering 195/311: timestep 194000
# Rendering 196/311: timestep 195000
# Rendering 197/311: timestep 196000
# Rendering 198/311: timestep 197000
# Rendering 199/311: timestep 198000
# Rendering 200/311: timestep 199000
# Rendering 201/311: timestep 200000
# Rendering 202/311: timestep 201000
# Rendering 203/311: timestep 202000
# Rendering 204/311: timestep 203000
# Rendering 205/311: timestep 204000
# Rendering 206/311: timestep 205000
# Rendering 207/311: timestep 206000
# Rendering 208/311: timestep 207000
# Rendering 209/311: timestep 208000
# Rendering 210/311: timestep 209000
# Rendering 211/311: timestep 210000
# Rendering 212/311: timestep 211000
# Rendering 213/311: timestep 212000
# Rendering 214/311: timestep 213000
# Rendering 215/311: timestep 214000
# Rendering 216/311: timestep 215000
# Rendering 217/311: timestep 216000
# Rendering 218/311: timestep 217000
# Rendering 219/311: timestep 218000
# Rendering 220/311: timestep 219000
# Rendering 221/311: timestep 220000
# Rendering 222/311: timestep 221000
# Rendering 223/311: timestep 222000
# Rendering 224/311: timestep 223000
# Rendering 225/311: timestep 224000
# Rendering 226/311: timestep 225000
# Rendering 227/311: timestep 226000
# Rendering 228/311: timestep 227000
# Rendering 229/311: timestep 228000
# Rendering 230/311: timestep 229000
# Rendering 231/311: timestep 230000
# Rendering 232/311: timestep 231000
# Rendering 233/311: timestep 232000
# Rendering 234/311: timestep 233000
# Rendering 235/311: timestep 234000
# Rendering 236/311: timestep 235000
# Rendering 237/311: timestep 236000
# Rendering 238/311: timestep 237000
# Rendering 239/311: timestep 238000
# Rendering 240/311: timestep 239000
# Rendering 241/311: timestep 240000
# Rendering 242/311: timestep 241000
# Rendering 243/311: timestep 242000
# Rendering 244/311: timestep 243000
# Rendering 245/311: timestep 244000
# Rendering 246/311: timestep 245000
# Rendering 247/311: timestep 246000
# Rendering 248/311: timestep 247000
# Rendering 249/311: timestep 248000
# Rendering 250/311: timestep 249000
# Rendering 251/311: timestep 250000
# Rendering 252/311: timestep 251000
# Rendering 253/311: timestep 252000
# Rendering 254/311: timestep 253000
# Rendering 255/311: timestep 254000
# Rendering 256/311: timestep 255000
# Rendering 257/311: timestep 256000
# Rendering 258/311: timestep 257000
# Rendering 259/311: timestep 258000
# Rendering 260/311: timestep 259000
# Rendering 261/311: timestep 260000
# Rendering 262/311: timestep 261000
# Rendering 263/311: timestep 262000
# Rendering 264/311: timestep 263000
# Rendering 265/311: timestep 264000
# Rendering 266/311: timestep 265000
# Rendering 267/311: timestep 266000
# Rendering 268/311: timestep 267000
# Rendering 269/311: timestep 268000
# Rendering 270/311: timestep 269000
# Rendering 271/311: timestep 270000
# Rendering 272/311: timestep 271000
# Rendering 273/311: timestep 272000
# Rendering 274/311: timestep 273000
# Rendering 275/311: timestep 274000
# Rendering 276/311: timestep 275000
# Rendering 277/311: timestep 276000
# Rendering 278/311: timestep 277000
# Rendering 279/311: timestep 278000
# Rendering 280/311: timestep 279000
# Rendering 281/311: timestep 280000
# Rendering 282/311: timestep 281000
# Rendering 283/311: timestep 282000
# Rendering 284/311: timestep 283000
# Rendering 285/311: timestep 284000
# Rendering 286/311: timestep 285000
# Rendering 287/311: timestep 286000
# Rendering 288/311: timestep 287000
# Rendering 289/311: timestep 288000
# Rendering 290/311: timestep 289000
# Rendering 291/311: timestep 290000
# Rendering 292/311: timestep 291000
# Rendering 293/311: timestep 292000
# Rendering 294/311: timestep 293000
# Rendering 295/311: timestep 294000
# Rendering 296/311: timestep 295000
# Rendering 297/311: timestep 296000
# Rendering 298/311: timestep 297000
# Rendering 299/311: timestep 298000
# Rendering 300/311: timestep 299000
# Rendering 301/311: timestep 300000
# Rendering 302/311: timestep 301000
# Rendering 303/311: timestep 302000
# Rendering 304/311: timestep 303000
# Rendering 305/311: timestep 304000
# Rendering 306/311: timestep 305000
# Rendering 307/311: timestep 306000
# Rendering 308/311: timestep 307000
# Rendering 309/311: timestep 308000
# Rendering 310/311: timestep 309000
# Rendering 311/311: timestep 310000
# ✅ 2D contour animation saved to: ../outputs/Results/20260727_131619/Electrodes_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
