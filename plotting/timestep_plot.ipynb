# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260721_204429"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 956 snapshots:
# Rendering 1/956: timestep 0
# Rendering 2/956: timestep 10000
# /tmp/ipykernel_3172073/1024534483.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 3/956: timestep 20000
# Rendering 4/956: timestep 30000
# Rendering 5/956: timestep 40000
# Rendering 6/956: timestep 50000
# Rendering 7/956: timestep 60000
# Rendering 8/956: timestep 70000
# Rendering 9/956: timestep 80000
# Rendering 10/956: timestep 90000
# Rendering 11/956: timestep 100000
# Rendering 12/956: timestep 110000
# Rendering 13/956: timestep 120000
# Rendering 14/956: timestep 130000
# Rendering 15/956: timestep 140000
# Rendering 16/956: timestep 150000
# Rendering 17/956: timestep 160000
# Rendering 18/956: timestep 170000
# Rendering 19/956: timestep 180000
# Rendering 20/956: timestep 190000
# Rendering 21/956: timestep 200000
# Rendering 22/956: timestep 210000
# Rendering 23/956: timestep 220000
# Rendering 24/956: timestep 230000
# Rendering 25/956: timestep 240000
# Rendering 26/956: timestep 250000
# Rendering 27/956: timestep 260000
# Rendering 28/956: timestep 270000
# Rendering 29/956: timestep 280000
# Rendering 30/956: timestep 290000
# Rendering 31/956: timestep 300000
# Rendering 32/956: timestep 310000
# Rendering 33/956: timestep 320000
# Rendering 34/956: timestep 330000
# Rendering 35/956: timestep 340000
# Rendering 36/956: timestep 350000
# Rendering 37/956: timestep 360000
# Rendering 38/956: timestep 370000
# Rendering 39/956: timestep 380000
# Rendering 40/956: timestep 390000
# Rendering 41/956: timestep 400000
# Rendering 42/956: timestep 410000
# Rendering 43/956: timestep 420000
# Rendering 44/956: timestep 430000
# Rendering 45/956: timestep 440000
# Rendering 46/956: timestep 450000
# Rendering 47/956: timestep 460000
# Rendering 48/956: timestep 470000
# Rendering 49/956: timestep 480000
# Rendering 50/956: timestep 490000
# Rendering 51/956: timestep 500000
# Rendering 52/956: timestep 510000
# Rendering 53/956: timestep 520000
# Rendering 54/956: timestep 530000
# Rendering 55/956: timestep 540000
# Rendering 56/956: timestep 550000
# Rendering 57/956: timestep 560000
# Rendering 58/956: timestep 570000
# Rendering 59/956: timestep 580000
# Rendering 60/956: timestep 590000
# Rendering 61/956: timestep 600000
# Rendering 62/956: timestep 610000
# Rendering 63/956: timestep 620000
# Rendering 64/956: timestep 630000
# Rendering 65/956: timestep 640000
# Rendering 66/956: timestep 650000
# Rendering 67/956: timestep 660000
# Rendering 68/956: timestep 670000
# Rendering 69/956: timestep 680000
# Rendering 70/956: timestep 690000
# Rendering 71/956: timestep 700000
# Rendering 72/956: timestep 710000
# Rendering 73/956: timestep 720000
# Rendering 74/956: timestep 730000
# Rendering 75/956: timestep 740000
# Rendering 76/956: timestep 750000
# Rendering 77/956: timestep 760000
# Rendering 78/956: timestep 770000
# Rendering 79/956: timestep 780000
# Rendering 80/956: timestep 790000
# Rendering 81/956: timestep 800000
# Rendering 82/956: timestep 810000
# Rendering 83/956: timestep 820000
# Rendering 84/956: timestep 830000
# Rendering 85/956: timestep 840000
# Rendering 86/956: timestep 850000
# Rendering 87/956: timestep 860000
# Rendering 88/956: timestep 870000
# Rendering 89/956: timestep 880000
# Rendering 90/956: timestep 890000
# Rendering 91/956: timestep 900000
# Rendering 92/956: timestep 910000
# Rendering 93/956: timestep 920000
# Rendering 94/956: timestep 930000
# Rendering 95/956: timestep 940000
# Rendering 96/956: timestep 950000
# Rendering 97/956: timestep 960000
# Rendering 98/956: timestep 970000
# Rendering 99/956: timestep 980000
# Rendering 100/956: timestep 990000
# Rendering 101/956: timestep 1000000
# Rendering 102/956: timestep 1010000
# Rendering 103/956: timestep 1020000
# Rendering 104/956: timestep 1030000
# Rendering 105/956: timestep 1040000
# Rendering 106/956: timestep 1050000
# Rendering 107/956: timestep 1060000
# Rendering 108/956: timestep 1070000
# Rendering 109/956: timestep 1080000
# Rendering 110/956: timestep 1090000
# Rendering 111/956: timestep 1100000
# Rendering 112/956: timestep 1110000
# Rendering 113/956: timestep 1120000
# Rendering 114/956: timestep 1130000
# Rendering 115/956: timestep 1140000
# Rendering 116/956: timestep 1150000
# Rendering 117/956: timestep 1160000
# Rendering 118/956: timestep 1170000
# Rendering 119/956: timestep 1180000
# Rendering 120/956: timestep 1190000
# Rendering 121/956: timestep 1200000
# Rendering 122/956: timestep 1210000
# Rendering 123/956: timestep 1220000
# Rendering 124/956: timestep 1230000
# Rendering 125/956: timestep 1240000
# Rendering 126/956: timestep 1250000
# Rendering 127/956: timestep 1260000
# Rendering 128/956: timestep 1270000
# Rendering 129/956: timestep 1280000
# Rendering 130/956: timestep 1290000
# Rendering 131/956: timestep 1300000
# Rendering 132/956: timestep 1310000
# Rendering 133/956: timestep 1320000
# Rendering 134/956: timestep 1330000
# Rendering 135/956: timestep 1340000
# Rendering 136/956: timestep 1350000
# Rendering 137/956: timestep 1360000
# Rendering 138/956: timestep 1370000
# Rendering 139/956: timestep 1380000
# Rendering 140/956: timestep 1390000
# Rendering 141/956: timestep 1400000
# Rendering 142/956: timestep 1410000
# Rendering 143/956: timestep 1420000
# Rendering 144/956: timestep 1430000
# Rendering 145/956: timestep 1440000
# Rendering 146/956: timestep 1450000
# Rendering 147/956: timestep 1460000
# Rendering 148/956: timestep 1470000
# Rendering 149/956: timestep 1480000
# Rendering 150/956: timestep 1490000
# Rendering 151/956: timestep 1500000
# Rendering 152/956: timestep 1510000
# Rendering 153/956: timestep 1520000
# Rendering 154/956: timestep 1530000
# Rendering 155/956: timestep 1540000
# Rendering 156/956: timestep 1550000
# Rendering 157/956: timestep 1560000
# Rendering 158/956: timestep 1570000
# Rendering 159/956: timestep 1580000
# Rendering 160/956: timestep 1590000
# Rendering 161/956: timestep 1600000
# Rendering 162/956: timestep 1610000
# Rendering 163/956: timestep 1620000
# Rendering 164/956: timestep 1630000
# Rendering 165/956: timestep 1640000
# Rendering 166/956: timestep 1650000
# Rendering 167/956: timestep 1660000
# Rendering 168/956: timestep 1670000
# Rendering 169/956: timestep 1680000
# Rendering 170/956: timestep 1690000
# Rendering 171/956: timestep 1700000
# Rendering 172/956: timestep 1710000
# Rendering 173/956: timestep 1720000
# Rendering 174/956: timestep 1730000
# Rendering 175/956: timestep 1740000
# Rendering 176/956: timestep 1750000
# Rendering 177/956: timestep 1760000
# Rendering 178/956: timestep 1770000
# Rendering 880/956: timestep 8790000
# Rendering 881/956: timestep 8800000
# Rendering 882/956: timestep 8810000
# Rendering 883/956: timestep 8820000
# Rendering 884/956: timestep 8830000
# Rendering 885/956: timestep 8840000
# Rendering 886/956: timestep 8850000
# Rendering 887/956: timestep 8860000
# Rendering 888/956: timestep 8870000
# Rendering 889/956: timestep 8880000
# Rendering 890/956: timestep 8890000
# Rendering 891/956: timestep 8900000
# Rendering 892/956: timestep 8910000
# Rendering 893/956: timestep 8920000
# Rendering 894/956: timestep 8930000
# Rendering 895/956: timestep 8940000
# Rendering 896/956: timestep 8950000
# Rendering 897/956: timestep 8960000
# Rendering 898/956: timestep 8970000
# Rendering 899/956: timestep 8980000
# Rendering 900/956: timestep 8990000
# Rendering 901/956: timestep 9000000
# Rendering 902/956: timestep 9010000
# Rendering 903/956: timestep 9020000
# Rendering 904/956: timestep 9030000
# Rendering 905/956: timestep 9040000
# Rendering 906/956: timestep 9050000
# Rendering 907/956: timestep 9060000
# Rendering 908/956: timestep 9070000
# Rendering 909/956: timestep 9080000
# Rendering 910/956: timestep 9090000
# Rendering 911/956: timestep 9100000
# Rendering 912/956: timestep 9110000
# Rendering 913/956: timestep 9120000
# Rendering 914/956: timestep 9130000
# Rendering 915/956: timestep 9140000
# Rendering 916/956: timestep 9150000
# Rendering 917/956: timestep 9160000
# Rendering 918/956: timestep 9170000
# Rendering 919/956: timestep 9180000
# Rendering 920/956: timestep 9190000
# Rendering 921/956: timestep 9200000
# Rendering 922/956: timestep 9210000
# Rendering 923/956: timestep 9220000
# Rendering 924/956: timestep 9230000
# Rendering 925/956: timestep 9240000
# Rendering 926/956: timestep 9250000
# Rendering 927/956: timestep 9260000
# Rendering 928/956: timestep 9270000
# Rendering 929/956: timestep 9280000
# Rendering 930/956: timestep 9290000
# Rendering 931/956: timestep 9300000
# Rendering 932/956: timestep 9310000
# Rendering 933/956: timestep 9320000
# Rendering 934/956: timestep 9330000
# Rendering 935/956: timestep 9340000
# Rendering 936/956: timestep 9350000
# Rendering 937/956: timestep 9360000
# Rendering 938/956: timestep 9370000
# Rendering 939/956: timestep 9380000
# Rendering 940/956: timestep 9390000
# Rendering 941/956: timestep 9400000
# Rendering 942/956: timestep 9410000
# Rendering 943/956: timestep 9420000
# Rendering 944/956: timestep 9430000
# Rendering 945/956: timestep 9440000
# Rendering 946/956: timestep 9450000
# Rendering 947/956: timestep 9460000
# Rendering 948/956: timestep 9470000
# Rendering 949/956: timestep 9480000
# Rendering 950/956: timestep 9490000
# Rendering 951/956: timestep 9500000
# Rendering 952/956: timestep 9510000
# Rendering 953/956: timestep 9520000
# Rendering 954/956: timestep 9530000
# Rendering 955/956: timestep 9540000
# Rendering 956/956: timestep 9550000
# ✅ 2D contour animation saved to: ../outputs/Results/20260721_204429/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
