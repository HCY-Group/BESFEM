# %% [markdown]
# --------------------------
#
# ## Plotting Using MFEM's PyGLViS
#
# More information: https://github.com/GLVis/pyglvis

# %%
# Pip installs pyglvis (and pymfem) if in a colab notebook. Can comment out if not required
# %pip install --quiet mfem==4.8.0 glvis
from glvis import glvis, GlvisData
import mfem.ser as mfem
import numpy as np
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
mesh = mfem.Mesh()

# mesh.Load("../outputs/Results/20260731_150049/pmesh")
# x = mfem.GridFunction(mesh, "../outputs/Results/20260730_131100/CnElectrodes_total_314000")
# x = mfem.GridFunction(mesh, "../outputs/Results/20260731_150049/CnA_total_00000")
mesh.Load("../bin/pmesh")
x = mfem.GridFunction(mesh, "../bin/AvP_Pair_0_1")
x1 = mfem.GridFunction(mesh, "../bin/AvP_Pair_1_2")
x2 = mfem.GridFunction(mesh, "../bin/AvP_Pair_0_2")


# x = mfem.GridFunction(mesh, "../bin/pse")


# mesh.Load("../bin/pmesh_before_amr")
# x = mfem.GridFunction(mesh, "../bin/psi_amr_level_0.gf")

# mesh.Load("../bin/boundary_mesh.000000")
# x = mfem.GridFunction(mesh, "../bin/pinned_bc")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 11
#       8 x1 = mfem.GridFunction(mesh, "../bin/AvP_Pair_1_2")
#       9 x2 = mfem.GridFunction(mesh, "../bin/AvP_Pair_0_2")
# ---> 11 x.Add(x1, 1.0)
#      12 x.Add(x2, 1.0)
#      14 # x = mfem.GridFunction(mesh, "../bin/pse")
#      15
#      16
#    (...)     20 # mesh.Load("../bin/boundary_mesh.000000")
#      21 # x = mfem.GridFunction(mesh, "../bin/pinned_bc")
#
# TypeError: in method 'Vector_Add', argument 2 of type 'mfem::real_t'

# %%
# Plot the mesh + solution (all GLVis keys and mouse commands work)
g = glvis((mesh, x3))
g
