# %% [markdown]
# --------------------------
#
# ## Plotting Using MFEM's PyGLViS
#
# More information: https://github.com/GLVis/pyglvis

# %%
# Pip installs pyglvis (and pymfem) if in a colab notebook. Can comment out if not required
# %pip install --quiet mfem==4.8.0 glvis
from glvis import glvis, GlvisData
import mfem.ser as mfem
import numpy as np
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
mesh = mfem.Mesh()

mesh.Load("../outputs/Results/20260728_082135/pmesh")
x = mfem.GridFunction(mesh, "../outputs/Results/20260728_082135/CnC_total_3000000")
# x = mfem.GridFunction(mesh, "../outputs/Results/20260727_131619/CnC_total_60000")
# mesh.Load("../bin/pmesh")
# x = mfem.GridFunction(mesh, "../bin/AvE")


# mesh.Load("../bin/pmesh_before_amr")
# x = mfem.GridFunction(mesh, "../bin/psi_amr_level_0.gf")

# mesh.Load("../bin/boundary_mesh.000000")
# x = mfem.GridFunction(mesh, "../bin/pinned_bc")
# Out:
# MFEM abort: input stream is not a FiniteElementSpace!
#  ... in function: mfem::FiniteElementCollection* mfem::FiniteElementSpace::Load(mfem::Mesh*, std::istream&)
#  ... in file: /__w/PyMFEM/PyMFEM/PyMFEM/external/mfem/fem/fespace.cpp:4507
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       1 mesh = mfem.Mesh()
#       3 mesh.Load("../outputs/Results/20260728_082135/pmesh")
# ----> 4 x = mfem.GridFunction(mesh, "../outputs/Results/20260728_082135/CnElectrodes_total_3000000")
#       5 # x = mfem.GridFunction(mesh, "../outputs/Results/20260727_131619/CnC_total_60000")
#       6 # mesh.Load("../bin/pmesh")
#       7 # x = mfem.GridFunction(mesh, "../bin/AvE")
#    (...)     13 # mesh.Load("../bin/boundary_mesh.000000")
#      14 # x = mfem.GridFunction(mesh, "../bin/pinned_bc")
#
# File ~/.local/lib/python3.11/site-packages/mfem/_ser/gridfunc.py:575, in GridFunction.__init__(self, *args)
#     564 def __init__(self, *args):
#     565     r"""
#     566     __init__(GridFunction self) -> GridFunction
#     567     __init__(GridFunction self, GridFunction orig) -> GridFunction
#    (...)    573     __init__(GridFunction self, FiniteElementSpace fes, Vector v, int offset) -> GridFunction
#     574     """
# --> 575     _gridfunc.GridFunction_swiginit(self, _gridfunc.new_GridFunction(*args))
#
# RuntimeError: PyMFEM error (mfem::ErrorException): MFEM abort: input stream is not a FiniteElementSpace!
#  ... in function: mfem::FiniteElementCollection* mfem::FiniteElementSpace::Load(mfem::Mesh*, std::istream&)
#  ... in file: /__w/PyMFEM/PyMFEM/PyMFEM/external/mfem/fem/fespace.cpp:4507

# %%
# Plot the mesh + solution (all GLVis keys and mouse commands work)
g = glvis((mesh, x))
g
