# %%
# !pip install scikit-image

# %%
import skimage as ski
import matplotlib.pyplot as plt
import numpy as np
import tifffile as tiff

# %%
# tif = ski.io.imread('../inputs/mesh/colored_labels_labels.tif');
# type(tif)
# tif.shape
# plt.imshow(tif);
# plt.colorbar()

# %%
arr = np.zeros([150,200])
for i in range(arr.shape[0]):
    if i < 30:
        arr[i,:] = 1.0

plt.imshow(arr)
plt.colorbar()

# %%
tiff.imwrite('../inputs/mesh/test_cathode.tif',arr)

# %%
tif = tiff.imread('../inputs/mesh/test_cathode.tif');
type(tif)
tif.shape
plt.imshow(tif);
plt.colorbar()
