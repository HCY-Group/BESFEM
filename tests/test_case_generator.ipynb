# %%
# !pip install scikit-image

# %%
import skimage as ski
import matplotlib.pyplot as plt
import numpy as np
import tifffile as tiff

# %%
arr = np.zeros([150,200], dtype=np.uint8)
for i in range(arr.shape[0]):
    if i > 30:
        arr[i,:] = 1

plt.imshow(arr)
plt.colorbar()
tiff.imwrite('../inputs/mesh/test_cathode.tif',arr)

# %%
arr = np.zeros([150,200], dtype=np.uint8)
for i in range(arr.shape[0]):
    if i < 30:
        arr[i,:] = 1

plt.imshow(arr)
plt.colorbar()
tiff.imwrite('../inputs/mesh/test_anode.tif',arr)

# %%
tif = tiff.imread('../inputs/mesh/test_cathode.tif');
type(tif)
tif.shape
plt.imshow(tif);
plt.colorbar()
